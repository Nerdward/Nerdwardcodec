# %%
#Import necessary libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import gc
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.metrics import fbeta_score
from tqdm import tqdm
import cv2
from PIL import Image
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

from sklearn.model_selection import train_test_split
from sklearn.metrics import fbeta_score

# %%
#Load train and test CSVs
df_train = pd.read_csv('../input/planets-dataset/planet/planet/train_classes.csv')
df_test = pd.read_csv('../input/planets-dataset/planet/planet/sample_submission.csv')

# %%
labels = df_train['tags'].apply(lambda x: x.split(' '))
from collections import Counter, defaultdict
counts = defaultdict(int) #dictionary containing each individual label
for l in labels:
    for l2 in l:
        counts[l2] += 1
tag_list=list(counts.keys()) 
y=list(counts.values())
#Create a dictionary assigning a numerical value to each label
label_map = {i:j for j, i in enumerate(tag_list)}
tag_list
# Out:
# ['haze',
#  'primary',
#  'agriculture',
#  'clear',
#  'water',
#  'habitation',
#  'road',
#  'cultivation',
#  'slash_burn',
#  'cloudy',
#  'partly_cloudy',
#  'conventional_mine',
#  'bare_ground',
#  'artisinal_mine',
#  'blooming',
#  'selective_logging',
#  'blow_down']

# %%
# One hot encode the training labels. Convert the images into pixels and resize them
X_train, Y_train = [], []
for img, label in tqdm(df_train.values, miniters = 1000):
  target = np.zeros(17)
  for tag in label.split(' '):
    target[label_map[tag]]=1
  X_train.append(cv2.resize(cv2.imread('../input/planets-dataset/planet/planet/train-jpg/{}.jpg'.format(img)), (64,64)))
  Y_train.append(target)
# Out:
# 100%|██████████| 40479/40479 [02:12<00:00, 304.70it/s]

# %%
#convert the test images to pixels and resize them as well
X_test=[]
for img, label in tqdm(df_test[:40669].values, miniters = 1000):
  X_test.append(cv2.resize(cv2.imread('../input/planets-dataset/planet/planet/test-jpg/{}.jpg'.format(img)), (64,64)))
for img, label in tqdm(df_test[40669:].values, miniters = 1000):
  X_test.append(cv2.resize(cv2.imread('../input/planets-dataset/test-jpg-additional/test-jpg-additional/{}.jpg'.format(img)), (64,64)))
# Out:
# 100%|██████████| 40669/40669 [02:33<00:00, 265.70it/s]
# 100%|██████████| 20522/20522 [01:15<00:00, 270.21it/s]

# %%
#Change lists to numpy arrays and normalize
X = np.array(X_train, np.float16)/255
y = np.array(Y_train, np.uint8)
X_test = np.array(X_test, np.float16)/255

# %%
np.save('./X',X)
np.save('./y',y)
np.save('./X_test',X_test)

# %%
# X = np.load('./X.npy')
# y = np.load('./y.npy')
# X_test = np.load('./X_test.npy')

# %%
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, shuffle = True, random_state = 1)

print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (32383, 64, 64, 3) (32383, 17) (8096, 64, 64, 3) (8096, 17)

# %%
del(X,y)

# %%
from keras_preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,                             
    horizontal_flip=True)

# %%
traingen = datagen.flow(x_train,
                       y_train,
                       batch_size=64)

# %%
from keras import backend as K


def fbeta(y_true, y_pred, threshold_shift=0):
    beta = 2

    # just in case of hipster activation at the final layer
    y_pred = K.clip(y_pred, 0, 1)

    # shifting the prediction threshold from .5 if needed
    y_pred_bin = K.round(y_pred + threshold_shift)

    tp = K.sum(K.round(y_true * y_pred_bin)) + K.epsilon()
    fp = K.sum(K.round(K.clip(y_pred_bin - y_true, 0, 1)))
    fn = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)))

    precision = tp / (tp + fp)
    recall = tp / (tp + fn)

    beta_squared = beta ** 2
    return (beta_squared + 1) * (precision * recall) / (beta_squared * precision + recall + K.epsilon())

# %%
from keras.applications.vgg19 import VGG19

# %%
base_model = VGG19(include_top=False,
                  weights='imagenet',
                  input_shape=(64,64,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
#kfold_weights_path = os.path.join('', 'weights_kfold_' + '.h5')
model = Sequential()
model.add(BatchNormalization(input_shape=(64, 64,3)))
model.add(base_model)
# model.add(Conv2D(32, kernel_size=(3, 3),padding='same', activation='relu'))
# model.add(Conv2D(32, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Conv2D(64, kernel_size=(3, 3),padding='same', activation='relu'))
# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
        
# model.add(Conv2D(128, kernel_size=(3, 3),padding='same', activation='relu'))
# model.add(Conv2D(128, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
        
# model.add(Conv2D(256, kernel_size=(3, 3),padding='same', activation='relu'))
# model.add(Conv2D(256, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
        
model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
model.add(Dense(17, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 64, 64, 3)         12
# _________________________________________________________________
# vgg19 (Functional)           (None, 2, 2, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 17)                34833
# =================================================================
# Total params: 20,059,229
# Trainable params: 20,059,223
# Non-trainable params: 6
# _________________________________________________________________

# %%
gc.enable()

# %%
#Try a combination of epoch lengths and learning rates
#batch_size=128
epochs = 20
learn_rate = 0.0001
opt  = optimizers.Adam(lr=learn_rate)
model.compile(loss='binary_crossentropy',optimizer=opt,metrics=[fbeta])
callbacks = [EarlyStopping(monitor='val_loss', patience=2, verbose=0),
            ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=1, cooldown=0, min_lr=1e-7, verbose=1),
            ModelCheckpoint(filepath='./weights_best.hdf5', verbose=1, save_best_only=True, 
                             save_weights_only=True, mode='auto')]

model.fit(traingen, 
          validation_data=(x_val, y_val),
          verbose=1, 
          epochs=epochs,
          callbacks=callbacks)
# Out:
# Epoch 1/20
# 506/506 [==============================] - ETA: 0s - loss: 0.1447 - fbeta: 0.7989
# Epoch 00001: val_loss improved from inf to 0.11871, saving model to ./weights_best.hdf5
# 506/506 [==============================] - 61s 121ms/step - loss: 0.1447 - fbeta: 0.7989 - val_loss: 0.1187 - val_fbeta: 0.8396
# Epoch 2/20
# 506/506 [==============================] - ETA: 0s - loss: 0.1202 - fbeta: 0.8362
# Epoch 00002: val_loss improved from 0.11871 to 0.11355, saving model to ./weights_best.hdf5
# 506/506 [==============================] - 60s 118ms/step - loss: 0.1202 - fbeta: 0.8362 - val_loss: 0.1136 - val_fbeta: 0.8717
# Epoch 3/20
# 506/506 [==============================] - ETA: 0s - loss: 0.1143 - fbeta: 0.8448
# Epoch 00003: val_loss improved from 0.11355 to 0.10807, saving model to ./weights_best.hdf5
# 506/506 [==============================] - 60s 118ms/step - loss: 0.1143 - fbeta: 0.8448 - val_loss: 0.1081 - val_fbeta: 0.8736
# Epoch 4/20
# 506/506 [==============================] - ETA: 0s - loss: 0.1107 - fbeta: 0.8505
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00004: val_loss did not improve from 0.10807
# 506/506 [==============================] - 59s 117ms/step - loss: 0.1107 - fbeta: 0.8505 - val_loss: 0.1115 - val_fbeta: 0.8585
# Epoch 5/20
# 506/506 [==============================] - ETA: 0s - loss: 0.0999 - fbeta: 0.8639
# Epoch 00005: val_loss improved from 0.10807 to 0.10029, saving model to ./weights_best.hdf5
# 506/506 [==============================] - 60s 118ms/step - loss: 0.0999 - fbeta: 0.8639 - val_loss: 0.1003 - val_fbeta: 0.8803
# Epoch 6/20
# 506/506 [==============================] - ETA: 0s - loss: 0.0977 - fbeta: 0.8687
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00006: val_loss did not improve from 0.10029
# 506/506 [==============================] - 59s 117ms/step - loss: 0.0977 - fbeta: 0.8687 - val_loss: 0.1016 - val_fbeta: 0.8804
# Epoch 7/20
# 506/506 [==============================] - ETA: 0s - loss: 0.0963 - fbeta: 0.8713
# Epoch 00007: val_loss improved from 0.10029 to 0.09910, saving model to ./weights_best.hdf5
# 506/506 [==============================] - 59s 117ms/step - loss: 0.0963 - fbeta: 0.8713 - val_loss: 0.0991 - val_fbeta: 0.8806
# Epoch 8/20
# 506/506 [==============================] - ETA: 0s - loss: 0.0960 - fbeta: 0.8711
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 00008: val_loss did not improve from 0.09910
# 506/506 [==============================] - 59s 116ms/step - loss: 0.0960 - fbeta: 0.8711 - val_loss: 0.1001 - val_fbeta: 0.8813
# Epoch 9/20
# 506/506 [==============================] - ETA: 0s - loss: 0.0957 - fbeta: 0.8720
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 00009: val_loss did not improve from 0.09910
# 506/506 [==============================] - 60s 118ms/step - loss: 0.0957 - fbeta: 0.8720 - val_loss: 0.0994 - val_fbeta: 0.8809

# %%
#from keras.models import load_weights
model.load_weights('./weights_best.hdf5')

# %%
yfull_test = []
yfull_train = []

p_val = model.predict(x_val, batch_size = 32, verbose=2)
print(fbeta_score(y_val, np.array(p_val) > 0.2, beta=2, average='samples')) #Check the model performance on the validation set

# p_train = model.predict(x_train, batch_size =128, verbose=2) #save the training predictions
# yfull_train.append(p_train)
        
# p_test = model.predict(x_test, batch_size = 128, verbose=2) #save the test predictions
# yfull_test.append(p_test)

# result = np.array(yfull_test[0])
# # for i in range(1, nfolds):
# #     result += np.array(yfull_test[i])
# # result /= nfolds
# result = pd.DataFrame(result, columns = labels)
# result
# Out:
# 253/253 - 3s
# 0.9134671275322496

# %%
predictions = model.predict(X_test)

# %%
tags = np.array(tag_list)

# %%
thres = 0.2
test_labels=[]
for i in tqdm(range(predictions.shape[0]),miniters=1000):
    label = predictions[i,:] > thres
    
    test_labels.append(list(tags[label]))
# Out:
# 100%|██████████| 61191/61191 [00:00<00:00, 111491.21it/s]

# %%
test_labels
# Out:
# [['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation', 'partly_cloudy'],
#  ['primary', 'cloudy', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['haze',
#   'primary',
#   'agriculture',
#   'clear',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road', 'selective_logging'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary', 'agriculture', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'agriculture', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'partly_cloudy'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation', 'partly_cloudy'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road', 'cultivation', 'artisinal_mine'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary',
#   'agriculture',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['haze', 'primary'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear', 'road', 'selective_logging'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['cloudy'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'cultivation'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'road', 'cultivation', 'partly_cloudy'],
#  ['primary', 'cloudy', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['clear', 'water', 'cloudy'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'clear'],
#  ['primary', 'clear', 'water', 'road', 'selective_logging'],
#  ['primary',
#   'agriculture',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'agriculture', 'road', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'cultivation', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'water', 'partly_cloudy'],
#  ['primary', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water'],
#  ['haze', 'primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary',
#   'agriculture',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'water', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'water', 'cultivation'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'partly_cloudy'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'water', 'partly_cloudy'],
#  ['haze',
#   'primary',
#   'agriculture',
#   'clear',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'partly_cloudy'],
#  ['haze', 'primary', 'clear'],
#  ['haze', 'primary', 'water', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'road', 'partly_cloudy'],
#  ['clear', 'water', 'cloudy'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'water', 'partly_cloudy'],
#  ['haze', 'primary'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'road',
#   'bare_ground',
#   'artisinal_mine'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['primary', 'partly_cloudy'],
#  ['haze', 'primary'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary',
#   'agriculture',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'road', 'cultivation', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['haze', 'primary'],
#  ['primary', 'clear', 'water', 'road', 'artisinal_mine'],
#  ['primary', 'clear', 'water', 'road', 'artisinal_mine'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'water', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'road', 'partly_cloudy'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'road', 'cultivation', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'water', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'water', 'road', 'selective_logging'],
#  ['primary', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'blooming', 'selective_logging'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['haze', 'primary', 'clear'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'road', 'cultivation', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'water', 'road', 'artisinal_mine'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['haze', 'primary', 'clear', 'water'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['haze', 'primary'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['haze', 'primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'road', 'bare_ground'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'water', 'road', 'partly_cloudy'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'cloudy', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['cloudy'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'cloudy', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'clear', 'blooming'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['haze', 'primary'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road', 'selective_logging'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road'],
#  ['water', 'cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'clear'],
#  ['haze', 'primary'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['haze', 'primary', 'cloudy'],
#  ['haze', 'primary', 'water', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['haze', 'primary'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'habitation', 'road', 'artisinal_mine'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['haze', 'primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['haze',
#   'primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear', 'water'],
#  ['haze', 'primary'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'clear'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'cultivation'],
#  ['primary', 'clear'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['primary', 'clear', 'water', 'road', 'selective_logging'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'cultivation', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'cultivation'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['clear', 'water', 'cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['haze', 'primary', 'agriculture', 'water', 'road'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['haze', 'primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'clear'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'cloudy', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'water', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'water',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'cultivation', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'cultivation', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['haze', 'primary'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road', 'artisinal_mine'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['haze', 'primary'],
#  ['primary', 'clear', 'blooming'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary',
#   'agriculture',
#   'water',
#   'road',
#   'partly_cloudy',
#   'artisinal_mine'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water', 'road'],
#  ['cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['haze', 'primary', 'agriculture', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear', 'blooming'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'clear', 'water', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'cultivation', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['haze', 'primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'agriculture', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road', 'partly_cloudy'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'water', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear', 'habitation', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['haze', 'primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'water', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road', 'artisinal_mine'],
#  ['primary', 'agriculture', 'habitation', 'cultivation', 'partly_cloudy'],
#  ['primary', 'agriculture', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['haze', 'primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['clear', 'water', 'cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['haze', 'primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'habitation', 'road', 'artisinal_mine'],
#  ['primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['haze', 'primary', 'agriculture', 'water', 'road'],
#  ['cloudy'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'road',
#   'bare_ground',
#   'artisinal_mine'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'bare_ground'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'water',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'partly_cloudy'],
#  ['primary', 'water', 'partly_cloudy'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'water', 'road', 'cultivation', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['haze', 'primary'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'cultivation', 'partly_cloudy'],
#  ['haze', 'primary'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'water', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary',
#   'agriculture',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['cloudy', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['cloudy'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'habitation', 'road', 'cloudy', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'water', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['cloudy'],
#  ['haze', 'primary'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary', 'agriculture', 'clear', 'road', 'selective_logging'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'water', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'water', 'partly_cloudy'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road', 'selective_logging'],
#  ['primary', 'agriculture', 'clear', 'water', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'clear', 'water', 'road', 'artisinal_mine'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'water', 'road', 'cultivation', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'road', 'cultivation'],
#  ['haze', 'primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'agriculture', 'cultivation', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['cloudy'],
#  ['primary', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'water'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'water', 'road'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'blooming', 'selective_logging'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary', 'agriculture', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear', 'road'],
#  ['cloudy'],
#  ['cloudy'],
#  ['primary', 'clear', 'water', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'water', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'partly_cloudy'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'partly_cloudy'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'cultivation'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'water', 'road', 'partly_cloudy'],
#  ['primary',
#   'agriculture',
#   'clear',
#   'water',
#   'habitation',
#   'road',
#   'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'cultivation'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'agriculture', 'water'],
#  ['primary',
#   'agriculture',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['haze', 'primary'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'road', 'bare_ground'],
#  ['primary', 'water', 'partly_cloudy'],
#  ['haze', 'primary', 'water'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary',
#   'agriculture',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'agriculture', 'road', 'cultivation', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['haze', 'primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'agriculture', 'water'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'clear'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'cloudy'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'cloudy', 'partly_cloudy'],
#  ['cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road', 'selective_logging'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'cultivation', 'partly_cloudy'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary', 'clear', 'water'],
#  ['primary', 'clear', 'water', 'road', 'selective_logging'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'partly_cloudy'],
#  ['cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear', 'water', 'road', 'selective_logging'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'clear', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'water', 'partly_cloudy'],
#  ['haze', 'primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['haze', 'primary', 'cloudy'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'road', 'cultivation', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary',
#   'agriculture',
#   'habitation',
#   'road',
#   'cultivation',
#   'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'road', 'bare_ground'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation'],
#  ['primary', 'clear'],
#  ['primary', 'partly_cloudy'],
#  ['primary', 'agriculture', 'clear', 'water', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'agriculture', 'clear', 'road', 'partly_cloudy'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['primary', 'agriculture', 'clear', 'water'],
#  ['haze', 'primary'],
#  ['primary', 'agriculture', 'clear', 'cultivation'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'habitation', 'road'],
#  ['primary', 'clear', 'water', 'road'],
#  ['primary', 'agriculture', 'clear', 'water', 'road', 'cultivation'],
#  ['primary', 'clear'],
#  ['primary', 'clear'],
#  ['haze', 'primary', 'clear'],
#  ['primary', 'clear'],
#  ...]

# %%
df_test.head()
# Out:
#   image_name                                  tags
# 0     test_0  primary clear agriculture road water
# 1     test_1  primary clear agriculture road water
# 2     test_2  primary clear agriculture road water
# 3     test_3  primary clear agriculture road water
# 4     test_4  primary clear agriculture road water

# %%
df_test['tags'] = test_labels

# %%
df_test.head()
# Out:
#   image_name                                               tags
# 0     test_0                                   [primary, clear]
# 1     test_1                                   [primary, clear]
# 2     test_2                           [primary, partly_cloudy]
# 3     test_3  [primary, agriculture, clear, cultivation, par...
# 4     test_4                   [primary, cloudy, partly_cloudy]

# %%
df_test['tags'] = df_test['tags'].str.join(' ')

# %%
df_test.shape
# Out:
# (61191, 2)

# %%
df_test.to_csv('submission.csv',index=False)
